# %%
### Import required libraries

import numpy as np
import pandas as pd
import gc

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from sklearn import model_selection
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import RobustScaler

import lightgbm as lgb
import xgboost as xgb
from catboost import CatBoostRegressor
from bayes_opt import BayesianOptimization
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import r2_score

from IPython.display import display # Allows the use of display() for DataFrames

import warnings
warnings.filterwarnings('ignore')

# %%
# Read train and test files
train_df = pd.read_csv('new_data/2016_to_2018_train_data.csv',encoding = "ISO-8859-1")
test_df = pd.read_csv('new_data/2019_test_data.csv',encoding = "ISO-8859-1")
train_df=train_df.rename(columns = {'Offer(Net Weight)':'Offer_Net_Weight'})
test_df=test_df.rename(columns = {'Offer(Net Weight)':'Offer_Net_Weight'})
train_df = train_df[train_df['Tealingo Item'].notna()]
test_df = test_df[test_df['Tealingo Item'].notna()]
test_df_ori = test_df

# %%
train_df['Offer_Net_Weight'] = train_df['Offer_Net_Weight'].str.replace(',', '')
test_df['Offer_Net_Weight'] = test_df['Offer_Net_Weight'].str.replace(',', '')
train_df['Manufacturing Date'] = train_df['Manufacturing Date'].str.replace('-', '.')
test_df['Manufacturing Date'] = test_df['Manufacturing Date'].str.replace('-', '.')

# %%
train_df = train_df[['Garden Mark','Garden Geo Orgin','Manufacturing Date','Tealingo Item','Offer_Net_Weight']]
train_df.head()
# Out:
#            Garden Mark Garden Geo Orgin Manufacturing Date Tealingo Item  \
# 0   ASHOK KUMAR ESTATE               SI         25.12.2015        EG36SI
# 1   ASHOK KUMAR ESTATE               SI         25.12.2015        DG36SI
# 2   ASHOK KUMAR ESTATE               SI         25.12.2015        CG36SI
# 3     HIGHFIELD ESTATE               SI         16.12.2015        EG33SI
# 4  ASHOK KUMAR SUPREME               SI         25.12.2015        EG35SI
#
#   Offer_Net_Weight
# 0              231
# 1              231
# 2              231
# 3              450
# 4              204

# %%
train_df['Manufacturing Date'] = pd.to_datetime(train_df['Manufacturing Date'], errors='coerce')
#train_df['Manufacturing Date'] = train_df['Manufacturing Date'].dt.year
#train_df['Manufacturing Date'] = train_df['Manufacturing Date'].dt.month

train_df['year'] = pd.DatetimeIndex(train_df['Manufacturing Date']).year
train_df['month'] = pd.DatetimeIndex(train_df['Manufacturing Date']).month

# %%
train_df['Manufacturing Date'] = train_df['month'].astype(str) + '.' + train_df['year'].astype(str) 

train_df.drop(['year', 'month'], axis=1)
train_df.head()
# Out:
#            Garden Mark Garden Geo Orgin Manufacturing Date Tealingo Item  \
# 0   ASHOK KUMAR ESTATE               SI            12.2015        EG36SI
# 1   ASHOK KUMAR ESTATE               SI            12.2015        DG36SI
# 2   ASHOK KUMAR ESTATE               SI            12.2015        CG36SI
# 3     HIGHFIELD ESTATE               SI            12.2015        EG33SI
# 4  ASHOK KUMAR SUPREME               SI            12.2015        EG35SI
#
#   Offer_Net_Weight  year  month
# 0              231  2015     12
# 1              231  2015     12
# 2              231  2015     12
# 3              450  2015     12
# 4              204  2015     12

# %%
test_df = test_df[['Garden Mark','Garden Geo Orgin','Manufacturing Date','Tealingo Item','Offer_Net_Weight']]
test_df['Manufacturing Date'] = pd.to_datetime(test_df['Manufacturing Date'], errors='coerce')

test_df['year'] = pd.DatetimeIndex(test_df['Manufacturing Date']).year
test_df['month'] = pd.DatetimeIndex(test_df['Manufacturing Date']).month

test_df['Manufacturing Date'] = test_df['month'].astype(str) + '.' + test_df['year'].astype(str) 

test_df = test_df[['Garden Mark','Garden Geo Orgin','Manufacturing Date','Tealingo Item','Offer_Net_Weight']] 
test_df.head()
# Out:
#           Garden Mark Garden Geo Orgin Manufacturing Date Tealingo Item  \
# 0  ASHOK KUMAR ESTATE               SI            12.2018        EG35SI
# 1  ASHOK KUMAR ESTATE               SI            12.2018        EG35SI
# 2  ASHOK KUMAR ESTATE               SI            12.2018        DG35SI
# 3  ASHOK KUMAR ESTATE               SI            12.2018        CG35SI
# 4  ASHOK KUMAR ESTATE               SI            12.2018        CG35SI
#
#   Offer_Net_Weight
# 0              238
# 1              238
# 2              238
# 3              238
# 4              238

# %%
#### Check if there are any NULL values in Test Data
print("Total Train Features with NaN Values = " + str(train_df.columns[train_df.isnull().sum() != 0].size))
if (train_df.columns[train_df.isnull().sum() != 0].size):
    print("Features with NaN => {}".format(list(train_df.columns[train_df.isnull().sum() != 0])))
    train_df[train_df.columns[train_df.isnull().sum() != 0]].isnull().sum().sort_values(ascending = False)
# Out:
# Total Train Features with NaN Values = 0

# %%
#### Check if there are any NULL values in Test Data
print("Total Test Features with NaN Values = " + str(test_df.columns[test_df.isnull().sum() != 0].size))
if (test_df.columns[test_df.isnull().sum() != 0].size):
    print("Features with NaN => {}".format(list(test_df.columns[test_df.isnull().sum() != 0])))
    test_df[test_df.columns[test_df.isnull().sum() != 0]].isnull().sum().sort_values(ascending = False)
# Out:
# Total Test Features with NaN Values = 0

# %%
train_df = train_df[['Garden Mark','Garden Geo Orgin','Manufacturing Date','Tealingo Item','Offer_Net_Weight']]
X = train_df.drop('Offer_Net_Weight', axis=1)
y = train_df.Offer_Net_Weight

# %%
y = y.astype(float)

# %%
y.dtype
# Out:
# dtype('float64')

# %%
for c in X.columns:
    col_type = X[c].dtype
    if col_type == 'object' or col_type.name == 'category':
        X[c] = X[c].astype('category')

# %%
#from sklearn.preprocessing import LabelEncoder
#for c in X.columns:
    #X[c] = LabelEncoder().fit_transform(X[c].values)

# %%
dtrain = lgb.Dataset(data=X, label=y)

# %%
def lgb_r2_score(preds, dtrain):
    labels = dtrain.get_label()
    return 'r2', r2_score(labels, preds), True

# %%
# Objective Function
def hyp_lgbm(num_leaves, feature_fraction, bagging_fraction, max_depth, min_split_gain, min_child_weight):
      
        params = {'application':'regression','num_iterations': 200,
                  'learning_rate':0.05, 'early_stopping_round':50,
                  'metric':'lgb_r2_score'} # Default parameters
        params["num_leaves"] = int(round(num_leaves))
        params['feature_fraction'] = max(min(feature_fraction, 1), 0)
        params['bagging_fraction'] = max(min(bagging_fraction, 1), 0)
        params['max_depth'] = int(round(max_depth))
        params['min_split_gain'] = min_split_gain
        params['min_child_weight'] = min_child_weight
        cv_results = lgb.cv(params, dtrain, nfold=5, seed=101,categorical_feature=[], stratified=False,
                            verbose_eval =None, feval=lgb_r2_score)
        # print(cv_results)
        return np.max(cv_results['r2-mean'])

# %%
# Domain space-- Range of hyperparameters 
pds = {'num_leaves': (80, 100),
          'feature_fraction': (0.1, 0.9),
          'bagging_fraction': (0.8, 1),
          'max_depth': (17, 25),
          'min_split_gain': (0.001, 0.1),
          'min_child_weight': (10, 25)
          }

# %%
# Surrogate model
optimizer = BayesianOptimization(hyp_lgbm, pds, random_state=77)
                                  
# Optimize
optimizer.maximize(init_points=5, n_iter=15)
# Out:
# |   iter    |  target   | baggin... | featur... | max_depth | min_ch... | min_sp... | num_le... |
# -------------------------------------------------------------------------------------------------
# |  1        |  0.4992   |  0.9838   |  0.6138   |  23.03    |  12.09    |  0.009645 |  95.76    |
# |  2        |  0.4986   |  0.8652   |  0.5329   |  18.92    |  18.18    |  0.04065  |  94.3     |
# |  3        |  0.4976   |  0.9673   |  0.5708   |  19.37    |  14.22    |  0.07085  |  88.45    |
# |  4        |  0.5211   |  0.8115   |  0.6976   |  20.62    |  12.64    |  0.005888 |  85.85    |
# |  5        |  0.5197   |  0.8134   |  0.7009   |  17.51    |  16.48    |  0.03705  |  83.04    |
# |  6        |  0.4961   |  1.0      |  0.1      |  25.0     |  25.0     |  0.1      |  80.0     |
# |  7        |  0.5287   |  0.8      |  0.9      |  25.0     |  25.0     |  0.001    |  100.0    |
# |  8        |  0.4961   |  0.9028   |  0.1017   |  24.81    |  10.04    |  0.04551  |  80.19    |
# |  9        |  0.5284   |  0.8      |  0.9      |  17.0     |  10.0     |  0.001    |  100.0    |
# |  10       |  0.5213   |  0.8      |  0.9      |  17.0     |  10.0     |  0.001    |  80.0     |
# |  11       |  0.4994   |  0.8516   |  0.2273   |  17.22    |  24.79    |  0.002123 |  99.99    |
# |  12       |  0.5191   |  0.9031   |  0.8146   |  17.11    |  24.83    |  0.01453  |  83.9     |
# |  13       |  0.5239   |  0.8201   |  0.8922   |  24.23    |  24.83    |  0.01863  |  86.5     |
# |  14       |  0.522    |  0.9195   |  0.8938   |  24.33    |  18.71    |  0.03774  |  80.0     |
# |  15       |  0.5256   |  0.8618   |  0.8548   |  24.96    |  15.62    |  0.02276  |  99.72    |
# |  16       |  0.5207   |  0.8268   |  0.8841   |  18.79    |  23.97    |  0.08162  |  80.02    |
# |  17       |  0.5249   |  0.8026   |  0.8949   |  24.95    |  12.99    |  0.0772   |  86.62    |
# |  18       |  0.5224   |  0.8099   |  0.899    |  22.07    |  11.32    |  0.07408  |  81.38    |
# |  19       |  0.4998   |  0.8154   |  0.4092   |  24.81    |  10.14    |  0.005677 |  99.79    |
# |  20       |  0.5284   |  0.8744   |  0.8952   |  17.3     |  16.99    |  0.01827  |  99.93    |
# =================================================================================================

# %%
optimizer.max
# Out:
# {'target': 0.5286821631103102,
#  'params': {'bagging_fraction': 0.8,
#   'feature_fraction': 0.9,
#   'max_depth': 25.0,
#   'min_child_weight': 25.0,
#   'min_split_gain': 0.001,
#   'num_leaves': 100.0}}

# %%
for c in X.columns:
    col_type = X[c].dtype
    if col_type == 'object' or col_type.name == 'category':
        X[c] = X[c].astype('category')

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3683134 entries, 0 to 3971158
# Data columns (total 4 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   Garden Mark         category
#  1   Garden Geo Orgin    category
#  2   Manufacturing Date  category
#  3   Tealingo Item       category
# dtypes: category(4)
# memory usage: 49.5 MB

# %%
X.columns
# Out:
# Index(['Garden Mark', 'Garden Geo Orgin', 'Manufacturing Date',
#        'Tealingo Item'],
#       dtype='object')

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.80, random_state=42)

# %%
tr_data = lgb.Dataset(X_train, label=y_train, categorical_feature=X.columns.tolist())
va_data = lgb.Dataset(X_test, label=y_test, categorical_feature=X.columns.tolist(), reference=tr_data)

# %%
X.columns.tolist()
# Out:
# ['Garden Mark', 'Garden Geo Orgin', 'Manufacturing Date', 'Tealingo Item']

# %%
y.dtype
# Out:
# dtype('float64')

# %%
va_data.data.head()
# Out:
#                Garden Mark Garden Geo Orgin Manufacturing Date Tealingo Item
# 2839720         ROCKVALLEY               SI             3.2018        GG45SI
# 1033742             DOORIA               AS             5.2016        FE15AS
# 1598888        GELAKEYBARI               AS             5.2017        IB26AS
# 353511       GARSWOOD GOLD               SI             6.2016        DG45SI
# 1454251  BHANDIGURI ESTEEM               CD            12.2016      JG35CD-S

# %%
tr_data.data.head()
# Out:
#                   Garden Mark Garden Geo Orgin Manufacturing Date  \
# 1115848                  TEOK               AS            10.2016
# 2200376               UMATARA               AS             7.2017
# 85546    VENKATESWARA SUPREME               SI             2.2016
# 2660705               MALPANI               AS             5.2017
# 3539192        SALKATHONI(CL)               AS             8.2018
#
#         Tealingo Item
# 1115848      DG24AS-S
# 2200376      DB15AS-S
# 85546          IB56SI
# 2660705        HE34AS
# 3539192        HE24AS

# %%
# Train the model
parameters = {
    'task': 'train',
    'boosting_type': 'gbdt',
    'objective': 'regression',
    'metric': 'rmse',
    'num_leaves': 31,
    'learning_rate': 0.05,
    'feature_fraction': 0.9,
    'bagging_fraction': 0.8,
    'bagging_freq': 5,
    'verbose': 50
}

# %%
model = lgb.train(parameters,tr_data,valid_sets=va_data,num_boost_round=100000,early_stopping_rounds=500,verbose_eval=50)
# Out:
# Training until validation scores don't improve for 500 rounds
# [50]	valid_0's rmse: 246.253
# [100]	valid_0's rmse: 231.889
# [150]	valid_0's rmse: 226.943
# [200]	valid_0's rmse: 224.207
# [250]	valid_0's rmse: 222.268
# [300]	valid_0's rmse: 220.596
# [350]	valid_0's rmse: 219.421
# [400]	valid_0's rmse: 218.265
# [450]	valid_0's rmse: 217.242
# [500]	valid_0's rmse: 216.286
# [550]	valid_0's rmse: 215.566
# [600]	valid_0's rmse: 214.979
# [650]	valid_0's rmse: 214.395
# [700]	valid_0's rmse: 213.88
# [750]	valid_0's rmse: 213.427
# [800]	valid_0's rmse: 213.083
# [850]	valid_0's rmse: 212.634
# [900]	valid_0's rmse: 212.279
# [950]	valid_0's rmse: 211.923
# [1000]	valid_0's rmse: 211.587
# [1050]	valid_0's rmse: 211.317
# [1100]	valid_0's rmse: 211.065
# [1150]	valid_0's rmse: 210.76
# [1200]	valid_0's rmse: 210.502
# [1250]	valid_0's rmse: 210.25
# [1300]	valid_0's rmse: 209.998
# [1350]	valid_0's rmse: 209.755
# [1400]	valid_0's rmse: 209.535
# [1450]	valid_0's rmse: 209.32
# [1500]	valid_0's rmse: 209.088
# [1550]	valid_0's rmse: 208.894
# [1600]	valid_0's rmse: 208.678
# [1650]	valid_0's rmse: 208.493
# [1700]	valid_0's rmse: 208.336
# [1750]	valid_0's rmse: 208.137
# [1800]	valid_0's rmse: 207.944
# [1850]	valid_0's rmse: 207.763
# [1900]	valid_0's rmse: 207.585
# [1950]	valid_0's rmse: 207.444
# [2000]	valid_0's rmse: 207.274
# [2050]	valid_0's rmse: 207.124
# [2100]	valid_0's rmse: 206.962
# [2150]	valid_0's rmse: 206.76
# [2200]	valid_0's rmse: 206.602
# [2250]	valid_0's rmse: 206.446
# [2300]	valid_0's rmse: 206.305
# [2350]	valid_0's rmse: 206.161
# [2400]	valid_0's rmse: 206.021
# [2450]	valid_0's rmse: 205.881
# [2500]	valid_0's rmse: 205.755
# [2550]	valid_0's rmse: 205.617
# [2600]	valid_0's rmse: 205.51
# [2650]	valid_0's rmse: 205.386
# [2700]	valid_0's rmse: 205.265
# [2750]	valid_0's rmse: 205.151
# [2800]	valid_0's rmse: 205.044
# [2850]	valid_0's rmse: 204.947
# [2900]	valid_0's rmse: 204.817
# [2950]	valid_0's rmse: 204.724
# [3000]	valid_0's rmse: 204.606
# [3050]	valid_0's rmse: 204.477
# [3100]	valid_0's rmse: 204.378
# [3150]	valid_0's rmse: 204.281
# [3200]	valid_0's rmse: 204.165
# [3250]	valid_0's rmse: 204.082
# [3300]	valid_0's rmse: 203.989
# [3350]	valid_0's rmse: 203.876
# [3400]	valid_0's rmse: 203.764
# [3450]	valid_0's rmse: 203.663
# [3500]	valid_0's rmse: 203.53
# [3550]	valid_0's rmse: 203.45
# [3600]	valid_0's rmse: 203.352
# [3650]	valid_0's rmse: 203.268
# [3700]	valid_0's rmse: 203.171
# [3750]	valid_0's rmse: 203.075
# [3800]	valid_0's rmse: 202.967
# [3850]	valid_0's rmse: 202.862
# [3900]	valid_0's rmse: 202.782
# [3950]	valid_0's rmse: 202.7
# [4000]	valid_0's rmse: 202.606
# [4050]	valid_0's rmse: 202.525
# [4100]	valid_0's rmse: 202.44
# [4150]	valid_0's rmse: 202.367
# [4200]	valid_0's rmse: 202.304
# [4250]	valid_0's rmse: 202.226
# [4300]	valid_0's rmse: 202.108
# [4350]	valid_0's rmse: 202.016
# [4400]	valid_0's rmse: 201.925
# [4450]	valid_0's rmse: 201.858
# [4500]	valid_0's rmse: 201.779
# [4550]	valid_0's rmse: 201.709
# [4600]	valid_0's rmse: 201.637
# [4650]	valid_0's rmse: 201.558
# [4700]	valid_0's rmse: 201.492
# [4750]	valid_0's rmse: 201.421
# [4800]	valid_0's rmse: 201.336
# [4850]	valid_0's rmse: 201.264
# [4900]	valid_0's rmse: 201.201
# [4950]	valid_0's rmse: 201.13
# [5000]	valid_0's rmse: 201.041
# [5050]	valid_0's rmse: 200.982
# [5100]	valid_0's rmse: 200.923
# [5150]	valid_0's rmse: 200.853
# [5200]	valid_0's rmse: 200.791
# [5250]	valid_0's rmse: 200.744
# [5300]	valid_0's rmse: 200.685
# [5350]	valid_0's rmse: 200.629
# [5400]	valid_0's rmse: 200.55
# [5450]	valid_0's rmse: 200.493
# [5500]	valid_0's rmse: 200.438
# [5550]	valid_0's rmse: 200.371
# [5600]	valid_0's rmse: 200.31
# [5650]	valid_0's rmse: 200.238
# [5700]	valid_0's rmse: 200.174
# [5750]	valid_0's rmse: 200.117
# [5800]	valid_0's rmse: 200.056
# [5850]	valid_0's rmse: 199.989
# [5900]	valid_0's rmse: 199.931
# [5950]	valid_0's rmse: 199.859
# [6000]	valid_0's rmse: 199.809
# [6050]	valid_0's rmse: 199.757
# [6100]	valid_0's rmse: 199.702
# [6150]	valid_0's rmse: 199.641
# [6200]	valid_0's rmse: 199.591
# [6250]	valid_0's rmse: 199.53
# [6300]	valid_0's rmse: 199.481
# [6350]	valid_0's rmse: 199.43
# [6400]	valid_0's rmse: 199.37
# [6450]	valid_0's rmse: 199.327
# [6500]	valid_0's rmse: 199.263
# [6550]	valid_0's rmse: 199.217
# [6600]	valid_0's rmse: 199.171
# [6650]	valid_0's rmse: 199.118
# [6700]	valid_0's rmse: 199.078
# [6750]	valid_0's rmse: 199.033
# [6800]	valid_0's rmse: 198.967
# [6850]	valid_0's rmse: 198.929
# [6900]	valid_0's rmse: 198.876
# [6950]	valid_0's rmse: 198.817
# [7000]	valid_0's rmse: 198.773
# [7050]	valid_0's rmse: 198.706
# [7100]	valid_0's rmse: 198.655
# [7150]	valid_0's rmse: 198.612
# [7200]	valid_0's rmse: 198.551
# [7250]	valid_0's rmse: 198.504
# [7300]	valid_0's rmse: 198.467
# [7350]	valid_0's rmse: 198.421
# [7400]	valid_0's rmse: 198.387
# [7450]	valid_0's rmse: 198.336
# [7500]	valid_0's rmse: 198.274
# [7550]	valid_0's rmse: 198.231
# [7600]	valid_0's rmse: 198.178
# [7650]	valid_0's rmse: 198.139
# [7700]	valid_0's rmse: 198.101
# [7750]	valid_0's rmse: 198.054
# [7800]	valid_0's rmse: 198.019
# [7850]	valid_0's rmse: 197.973
# [7900]	valid_0's rmse: 197.941
# [7950]	valid_0's rmse: 197.891
# [8000]	valid_0's rmse: 197.855
# [8050]	valid_0's rmse: 197.823
# [8100]	valid_0's rmse: 197.79
# [8150]	valid_0's rmse: 197.735
# [8200]	valid_0's rmse: 197.685
# [8250]	valid_0's rmse: 197.611
# [8300]	valid_0's rmse: 197.577
# [8350]	valid_0's rmse: 197.533
# [8400]	valid_0's rmse: 197.5
# [8450]	valid_0's rmse: 197.459
# [8500]	valid_0's rmse: 197.423
# [8550]	valid_0's rmse: 197.39
# [8600]	valid_0's rmse: 197.352
# [8650]	valid_0's rmse: 197.325
# [8700]	valid_0's rmse: 197.291
# [8750]	valid_0's rmse: 197.255
# [8800]	valid_0's rmse: 197.216
# [8850]	valid_0's rmse: 197.19
# [8900]	valid_0's rmse: 197.15
# [8950]	valid_0's rmse: 197.121
# [9000]	valid_0's rmse: 197.084
# [9050]	valid_0's rmse: 197.052
# [9100]	valid_0's rmse: 197.021
# [9150]	valid_0's rmse: 196.987
# [9200]	valid_0's rmse: 196.949
# [9250]	valid_0's rmse: 196.915
# [9300]	valid_0's rmse: 196.879
# [9350]	valid_0's rmse: 196.839
# [9400]	valid_0's rmse: 196.813
# [9450]	valid_0's rmse: 196.792
# [9500]	valid_0's rmse: 196.759
# [9550]	valid_0's rmse: 196.724
# [9600]	valid_0's rmse: 196.689
# [9650]	valid_0's rmse: 196.653
# [9700]	valid_0's rmse: 196.618
# [9750]	valid_0's rmse: 196.592
# [9800]	valid_0's rmse: 196.567
# [9850]	valid_0's rmse: 196.535
# [9900]	valid_0's rmse: 196.507
# [9950]	valid_0's rmse: 196.484
# [10000]	valid_0's rmse: 196.461
# [10050]	valid_0's rmse: 196.419
# [10100]	valid_0's rmse: 196.392
# [10150]	valid_0's rmse: 196.357
# [10200]	valid_0's rmse: 196.333
# [10250]	valid_0's rmse: 196.309
# [10300]	valid_0's rmse: 196.278
# [10350]	valid_0's rmse: 196.251
# [10400]	valid_0's rmse: 196.206
# [10450]	valid_0's rmse: 196.189
# [10500]	valid_0's rmse: 196.164
# [10550]	valid_0's rmse: 196.133
# [10600]	valid_0's rmse: 196.102
# [10650]	valid_0's rmse: 196.074
# [10700]	valid_0's rmse: 196.059
# [10750]	valid_0's rmse: 196.03
# [10800]	valid_0's rmse: 196.004
# [10850]	valid_0's rmse: 195.98
# [10900]	valid_0's rmse: 195.951
# [10950]	valid_0's rmse: 195.928
# [11000]	valid_0's rmse: 195.908
# [11050]	valid_0's rmse: 195.882
# [11100]	valid_0's rmse: 195.86
# [11150]	valid_0's rmse: 195.843
# [11200]	valid_0's rmse: 195.821
# [11250]	valid_0's rmse: 195.802
# [11300]	valid_0's rmse: 195.773
# [11350]	valid_0's rmse: 195.755
# [11400]	valid_0's rmse: 195.725
# [11450]	valid_0's rmse: 195.702
# [11500]	valid_0's rmse: 195.679
# [11550]	valid_0's rmse: 195.66
# [11600]	valid_0's rmse: 195.637
# [11650]	valid_0's rmse: 195.61
# [11700]	valid_0's rmse: 195.584
# [11750]	valid_0's rmse: 195.555
# [11800]	valid_0's rmse: 195.522
# [11850]	valid_0's rmse: 195.499
# [11900]	valid_0's rmse: 195.465
# [11950]	valid_0's rmse: 195.438
# [12000]	valid_0's rmse: 195.422
# [12050]	valid_0's rmse: 195.413
# [12100]	valid_0's rmse: 195.393
# [12150]	valid_0's rmse: 195.366
# [12200]	valid_0's rmse: 195.326
# [12250]	valid_0's rmse: 195.295
# [12300]	valid_0's rmse: 195.275
# [12350]	valid_0's rmse: 195.245
# [12400]	valid_0's rmse: 195.218
# [12450]	valid_0's rmse: 195.197
# [12500]	valid_0's rmse: 195.176
# [12550]	valid_0's rmse: 195.153
# [12600]	valid_0's rmse: 195.134
# [12650]	valid_0's rmse: 195.111
# [12700]	valid_0's rmse: 195.086
# [12750]	valid_0's rmse: 195.067
# [12800]	valid_0's rmse: 195.046
# [12850]	valid_0's rmse: 195.022
# [12900]	valid_0's rmse: 194.997
# [12950]	valid_0's rmse: 194.978
# [13000]	valid_0's rmse: 194.974
# [13050]	valid_0's rmse: 194.952
# [13100]	valid_0's rmse: 194.913
# [13150]	valid_0's rmse: 194.895
# [13200]	valid_0's rmse: 194.871
# [13250]	valid_0's rmse: 194.849
# [13300]	valid_0's rmse: 194.829
# [13350]	valid_0's rmse: 194.815
# [13400]	valid_0's rmse: 194.796
# [13450]	valid_0's rmse: 194.776
# [13500]	valid_0's rmse: 194.755
# [13550]	valid_0's rmse: 194.732
# [13600]	valid_0's rmse: 194.707
# [13650]	valid_0's rmse: 194.695
# [13700]	valid_0's rmse: 194.67
# [13750]	valid_0's rmse: 194.657
# [13800]	valid_0's rmse: 194.637
# [13850]	valid_0's rmse: 194.622
# [13900]	valid_0's rmse: 194.601
# [13950]	valid_0's rmse: 194.583
# [14000]	valid_0's rmse: 194.562
# [14050]	valid_0's rmse: 194.551
# [14100]	valid_0's rmse: 194.522
# [14150]	valid_0's rmse: 194.496
# [14200]	valid_0's rmse: 194.482
# [14250]	valid_0's rmse: 194.464
# [14300]	valid_0's rmse: 194.445
# [14350]	valid_0's rmse: 194.424
# [14400]	valid_0's rmse: 194.41
# [14450]	valid_0's rmse: 194.386
# [14500]	valid_0's rmse: 194.375
# [14550]	valid_0's rmse: 194.353
# [14600]	valid_0's rmse: 194.335
# [14650]	valid_0's rmse: 194.313
# [14700]	valid_0's rmse: 194.305
# [14750]	valid_0's rmse: 194.286
# [14800]	valid_0's rmse: 194.262
# [14850]	valid_0's rmse: 194.243
# [14900]	valid_0's rmse: 194.226
# [14950]	valid_0's rmse: 194.206
# [15000]	valid_0's rmse: 194.192
# [15050]	valid_0's rmse: 194.169
# [15100]	valid_0's rmse: 194.158
# [15150]	valid_0's rmse: 194.134
# [15200]	valid_0's rmse: 194.121
# [15250]	valid_0's rmse: 194.103
# [15300]	valid_0's rmse: 194.088
# [15350]	valid_0's rmse: 194.074
# [15400]	valid_0's rmse: 194.062
# [15450]	valid_0's rmse: 194.051
# [15500]	valid_0's rmse: 194.044
# [15550]	valid_0's rmse: 194.028
# [15600]	valid_0's rmse: 194.013
# [15650]	valid_0's rmse: 193.995
# [15700]	valid_0's rmse: 193.985
# [15750]	valid_0's rmse: 193.97
# [15800]	valid_0's rmse: 193.951
# [15850]	valid_0's rmse: 193.939
# [15900]	valid_0's rmse: 193.924
# [15950]	valid_0's rmse: 193.915
# [16000]	valid_0's rmse: 193.9
# [16050]	valid_0's rmse: 193.88
# [16100]	valid_0's rmse: 193.853
# [16150]	valid_0's rmse: 193.829
# [16200]	valid_0's rmse: 193.813
# [16250]	valid_0's rmse: 193.795
# [16300]	valid_0's rmse: 193.792
# [16350]	valid_0's rmse: 193.78
# [16400]	valid_0's rmse: 193.763
# [16450]	valid_0's rmse: 193.749
# [16500]	valid_0's rmse: 193.741
# [16550]	valid_0's rmse: 193.723
# [16600]	valid_0's rmse: 193.711
# [16650]	valid_0's rmse: 193.695
# [16700]	valid_0's rmse: 193.681
# [16750]	valid_0's rmse: 193.662
# [16800]	valid_0's rmse: 193.638
# [16850]	valid_0's rmse: 193.628
# [16900]	valid_0's rmse: 193.617
# [16950]	valid_0's rmse: 193.594
# [17000]	valid_0's rmse: 193.578
# [17050]	valid_0's rmse: 193.56
# [17100]	valid_0's rmse: 193.554
# [17150]	valid_0's rmse: 193.545
# [17200]	valid_0's rmse: 193.527
# [17250]	valid_0's rmse: 193.516
# [17300]	valid_0's rmse: 193.495
# [17350]	valid_0's rmse: 193.479
# [17400]	valid_0's rmse: 193.461
# [17450]	valid_0's rmse: 193.447
# [17500]	valid_0's rmse: 193.433
# [17550]	valid_0's rmse: 193.42
# [17600]	valid_0's rmse: 193.399
# [17650]	valid_0's rmse: 193.391
# [17700]	valid_0's rmse: 193.382
# [17750]	valid_0's rmse: 193.367
# [17800]	valid_0's rmse: 193.347
# [17850]	valid_0's rmse: 193.341
# [17900]	valid_0's rmse: 193.332
# [17950]	valid_0's rmse: 193.322
# [18000]	valid_0's rmse: 193.309
# [18050]	valid_0's rmse: 193.294
# [18100]	valid_0's rmse: 193.287
# [18150]	valid_0's rmse: 193.271
# [18200]	valid_0's rmse: 193.274
# [18250]	valid_0's rmse: 193.263
# [18300]	valid_0's rmse: 193.254
# [18350]	valid_0's rmse: 193.243
# [18400]	valid_0's rmse: 193.227
# [18450]	valid_0's rmse: 193.209
# [18500]	valid_0's rmse: 193.196
# [18550]	valid_0's rmse: 193.18
# [18600]	valid_0's rmse: 193.169
# [18650]	valid_0's rmse: 193.169
# [18700]	valid_0's rmse: 193.155
# [18750]	valid_0's rmse: 193.153
# [18800]	valid_0's rmse: 193.146
# [18850]	valid_0's rmse: 193.134
# [18900]	valid_0's rmse: 193.121
# [18950]	valid_0's rmse: 193.114
# [19000]	valid_0's rmse: 193.105
# [19050]	valid_0's rmse: 193.094
# [19100]	valid_0's rmse: 193.086
# [19150]	valid_0's rmse: 193.068
# [19200]	valid_0's rmse: 193.052
# [19250]	valid_0's rmse: 193.052
# [19300]	valid_0's rmse: 193.039
# [19350]	valid_0's rmse: 193.028
# [19400]	valid_0's rmse: 193.014
# [19450]	valid_0's rmse: 193.001
# [19500]	valid_0's rmse: 192.995
# [19550]	valid_0's rmse: 192.987
# [19600]	valid_0's rmse: 192.986
# [19650]	valid_0's rmse: 192.973
# [19700]	valid_0's rmse: 192.962
# [19750]	valid_0's rmse: 192.956
# [19800]	valid_0's rmse: 192.947
# [19850]	valid_0's rmse: 192.941
# [19900]	valid_0's rmse: 192.935
# [19950]	valid_0's rmse: 192.925
# [20000]	valid_0's rmse: 192.913
# [20050]	valid_0's rmse: 192.903
# [20100]	valid_0's rmse: 192.898
# [20150]	valid_0's rmse: 192.89
# [20200]	valid_0's rmse: 192.886
# [20250]	valid_0's rmse: 192.876
# [20300]	valid_0's rmse: 192.862
# [20350]	valid_0's rmse: 192.856
# [20400]	valid_0's rmse: 192.845
# [20450]	valid_0's rmse: 192.832
# [20500]	valid_0's rmse: 192.825
# [20550]	valid_0's rmse: 192.813
# [20600]	valid_0's rmse: 192.799
# [20650]	valid_0's rmse: 192.789
# [20700]	valid_0's rmse: 192.784
# [20750]	valid_0's rmse: 192.784
# [20800]	valid_0's rmse: 192.777
# [20850]	valid_0's rmse: 192.763
# [20900]	valid_0's rmse: 192.752
# [20950]	valid_0's rmse: 192.743
# [21000]	valid_0's rmse: 192.732
# [21050]	valid_0's rmse: 192.722
# [21100]	valid_0's rmse: 192.712
# [21150]	valid_0's rmse: 192.715
# [21200]	valid_0's rmse: 192.707
# [21250]	valid_0's rmse: 192.698
# [21300]	valid_0's rmse: 192.696
# [21350]	valid_0's rmse: 192.692
# [21400]	valid_0's rmse: 192.677
# [21450]	valid_0's rmse: 192.676
# [21500]	valid_0's rmse: 192.673
# [21550]	valid_0's rmse: 192.662
# [21600]	valid_0's rmse: 192.655
# [21650]	valid_0's rmse: 192.645
# [21700]	valid_0's rmse: 192.64
# [21750]	valid_0's rmse: 192.637
# [21800]	valid_0's rmse: 192.626
# [21850]	valid_0's rmse: 192.624
# [21900]	valid_0's rmse: 192.624
# [21950]	valid_0's rmse: 192.625
# [22000]	valid_0's rmse: 192.613
# [22050]	valid_0's rmse: 192.613
# [22100]	valid_0's rmse: 192.597
# [22150]	valid_0's rmse: 192.593
# [22200]	valid_0's rmse: 192.593
# [22250]	valid_0's rmse: 192.585
# [22300]	valid_0's rmse: 192.569
# [22350]	valid_0's rmse: 192.568
# [22400]	valid_0's rmse: 192.569
# [22450]	valid_0's rmse: 192.558
# [22500]	valid_0's rmse: 192.552
# [22550]	valid_0's rmse: 192.55
# [22600]	valid_0's rmse: 192.532
# [22650]	valid_0's rmse: 192.533
# [22700]	valid_0's rmse: 192.527
# [22750]	valid_0's rmse: 192.516
# [22800]	valid_0's rmse: 192.503
# [22850]	valid_0's rmse: 192.5
# [22900]	valid_0's rmse: 192.491
# [22950]	valid_0's rmse: 192.48
# [23000]	valid_0's rmse: 192.473
# [23050]	valid_0's rmse: 192.46
# [23100]	valid_0's rmse: 192.449
# [23150]	valid_0's rmse: 192.445
# [23200]	valid_0's rmse: 192.438
# [23250]	valid_0's rmse: 192.431
# [23300]	valid_0's rmse: 192.428
# [23350]	valid_0's rmse: 192.43
# [23400]	valid_0's rmse: 192.422
# [23450]	valid_0's rmse: 192.414
# [23500]	valid_0's rmse: 192.41
# [23550]	valid_0's rmse: 192.405
# [23600]	valid_0's rmse: 192.4
# [23650]	valid_0's rmse: 192.386
# [23700]	valid_0's rmse: 192.384
# [23750]	valid_0's rmse: 192.377
# [23800]	valid_0's rmse: 192.375
# [23850]	valid_0's rmse: 192.373
# [23900]	valid_0's rmse: 192.372
# [23950]	valid_0's rmse: 192.362
# [24000]	valid_0's rmse: 192.359
# [24050]	valid_0's rmse: 192.346
# [24100]	valid_0's rmse: 192.344
# [24150]	valid_0's rmse: 192.333
# [24200]	valid_0's rmse: 192.33
# [24250]	valid_0's rmse: 192.327
# [24300]	valid_0's rmse: 192.322
# [24350]	valid_0's rmse: 192.314
# [24400]	valid_0's rmse: 192.311
# [24450]	valid_0's rmse: 192.31
# [24500]	valid_0's rmse: 192.299
# [24550]	valid_0's rmse: 192.286
# [24600]	valid_0's rmse: 192.275
# [24650]	valid_0's rmse: 192.265
# [24700]	valid_0's rmse: 192.258
# [24750]	valid_0's rmse: 192.254
# [24800]	valid_0's rmse: 192.249
# [24850]	valid_0's rmse: 192.245
# [24900]	valid_0's rmse: 192.239
# [24950]	valid_0's rmse: 192.232
# [25000]	valid_0's rmse: 192.227
# [25050]	valid_0's rmse: 192.219
# [25100]	valid_0's rmse: 192.215
# [25150]	valid_0's rmse: 192.217
# [25200]	valid_0's rmse: 192.209
# [25250]	valid_0's rmse: 192.196
# [25300]	valid_0's rmse: 192.194
# [25350]	valid_0's rmse: 192.191
# [25400]	valid_0's rmse: 192.19
# [25450]	valid_0's rmse: 192.18
# [25500]	valid_0's rmse: 192.168
# [25550]	valid_0's rmse: 192.165
# [25600]	valid_0's rmse: 192.163
# [25650]	valid_0's rmse: 192.16
# [25700]	valid_0's rmse: 192.153
# [25750]	valid_0's rmse: 192.152
# [25800]	valid_0's rmse: 192.147
# [25850]	valid_0's rmse: 192.146
# [25900]	valid_0's rmse: 192.142
# [25950]	valid_0's rmse: 192.132
# [26000]	valid_0's rmse: 192.125
# [26050]	valid_0's rmse: 192.122
# [26100]	valid_0's rmse: 192.11
# [26150]	valid_0's rmse: 192.107
# [26200]	valid_0's rmse: 192.107
# [26250]	valid_0's rmse: 192.108
# [26300]	valid_0's rmse: 192.099
# [26350]	valid_0's rmse: 192.088
# [26400]	valid_0's rmse: 192.081
# [26450]	valid_0's rmse: 192.077
# [26500]	valid_0's rmse: 192.073
# [26550]	valid_0's rmse: 192.079
# [26600]	valid_0's rmse: 192.071
# [26650]	valid_0's rmse: 192.067
# [26700]	valid_0's rmse: 192.065
# [26750]	valid_0's rmse: 192.063
# [26800]	valid_0's rmse: 192.052
# [26850]	valid_0's rmse: 192.046
# [26900]	valid_0's rmse: 192.038
# [26950]	valid_0's rmse: 192.033
# [27000]	valid_0's rmse: 192.03
# [27050]	valid_0's rmse: 192.03
# [27100]	valid_0's rmse: 192.023
# [27150]	valid_0's rmse: 192.018
# [27200]	valid_0's rmse: 192.015
# [27250]	valid_0's rmse: 192.004
# [27300]	valid_0's rmse: 192.004
# [27350]	valid_0's rmse: 192.006
# [27400]	valid_0's rmse: 192
# [27450]	valid_0's rmse: 191.995
# [27500]	valid_0's rmse: 191.99
# [27550]	valid_0's rmse: 191.986
# [27600]	valid_0's rmse: 191.986
# [27650]	valid_0's rmse: 191.987
# [27700]	valid_0's rmse: 191.983
# [27750]	valid_0's rmse: 191.988
# [27800]	valid_0's rmse: 191.981
# [27850]	valid_0's rmse: 191.975
# [27900]	valid_0's rmse: 191.973
# [27950]	valid_0's rmse: 191.965
# [28000]	valid_0's rmse: 191.96
# [28050]	valid_0's rmse: 191.955
# [28100]	valid_0's rmse: 191.952
# [28150]	valid_0's rmse: 191.947
# [28200]	valid_0's rmse: 191.938
# [28250]	valid_0's rmse: 191.942
# [28300]	valid_0's rmse: 191.942
# [28350]	valid_0's rmse: 191.937
# [28400]	valid_0's rmse: 191.926
# [28450]	valid_0's rmse: 191.926
# [28500]	valid_0's rmse: 191.919
# [28550]	valid_0's rmse: 191.912
# [28600]	valid_0's rmse: 191.911
# [28650]	valid_0's rmse: 191.912
# [28700]	valid_0's rmse: 191.908
# [28750]	valid_0's rmse: 191.909
# [28800]	valid_0's rmse: 191.91
# [28850]	valid_0's rmse: 191.905
# [28900]	valid_0's rmse: 191.9
# [28950]	valid_0's rmse: 191.907
# [29000]	valid_0's rmse: 191.905
# [29050]	valid_0's rmse: 191.906
# [29100]	valid_0's rmse: 191.902
# [29150]	valid_0's rmse: 191.903
# [29200]	valid_0's rmse: 191.905
# [29250]	valid_0's rmse: 191.901
# [29300]	valid_0's rmse: 191.895
# [29350]	valid_0's rmse: 191.896
# [29400]	valid_0's rmse: 191.881
# [29450]	valid_0's rmse: 191.879
# [29500]	valid_0's rmse: 191.871
# [29550]	valid_0's rmse: 191.868
# [29600]	valid_0's rmse: 191.864
# [29650]	valid_0's rmse: 191.86
# [29700]	valid_0's rmse: 191.856
# [29750]	valid_0's rmse: 191.848
# [29800]	valid_0's rmse: 191.844
# [29850]	valid_0's rmse: 191.845
# [29900]	valid_0's rmse: 191.838
# [29950]	valid_0's rmse: 191.835
# [30000]	valid_0's rmse: 191.828
# [30050]	valid_0's rmse: 191.828
# [30100]	valid_0's rmse: 191.826
# [30150]	valid_0's rmse: 191.827
# [30200]	valid_0's rmse: 191.818
# [30250]	valid_0's rmse: 191.809
# [30300]	valid_0's rmse: 191.813
# [30350]	valid_0's rmse: 191.813
# [30400]	valid_0's rmse: 191.812
# [30450]	valid_0's rmse: 191.812
# [30500]	valid_0's rmse: 191.804
# [30550]	valid_0's rmse: 191.796
# [30600]	valid_0's rmse: 191.794
# [30650]	valid_0's rmse: 191.793
# [30700]	valid_0's rmse: 191.79
# [30750]	valid_0's rmse: 191.787
# [30800]	valid_0's rmse: 191.789
# [30850]	valid_0's rmse: 191.784
# [30900]	valid_0's rmse: 191.788
# [30950]	valid_0's rmse: 191.782
# [31000]	valid_0's rmse: 191.77
# [31050]	valid_0's rmse: 191.768
# [31100]	valid_0's rmse: 191.765
# [31150]	valid_0's rmse: 191.764
# [31200]	valid_0's rmse: 191.764
# [31250]	valid_0's rmse: 191.755
# [31300]	valid_0's rmse: 191.75
# [31350]	valid_0's rmse: 191.752
# [31400]	valid_0's rmse: 191.752
# [31450]	valid_0's rmse: 191.746
# [31500]	valid_0's rmse: 191.747
# [31550]	valid_0's rmse: 191.75
# [31600]	valid_0's rmse: 191.743
# [31650]	valid_0's rmse: 191.735
# [31700]	valid_0's rmse: 191.741
# [31750]	valid_0's rmse: 191.727
# [31800]	valid_0's rmse: 191.72
# [31850]	valid_0's rmse: 191.713
# [31900]	valid_0's rmse: 191.717
# [31950]	valid_0's rmse: 191.71
# [32000]	valid_0's rmse: 191.716
# [32050]	valid_0's rmse: 191.716
# [32100]	valid_0's rmse: 191.71
# [32150]	valid_0's rmse: 191.707
# [32200]	valid_0's rmse: 191.708
# [32250]	valid_0's rmse: 191.7
# [32300]	valid_0's rmse: 191.699
# [32350]	valid_0's rmse: 191.696
# [32400]	valid_0's rmse: 191.701
# [32450]	valid_0's rmse: 191.692
# [32500]	valid_0's rmse: 191.689
# [32550]	valid_0's rmse: 191.69
# [32600]	valid_0's rmse: 191.687
# [32650]	valid_0's rmse: 191.691
# [32700]	valid_0's rmse: 191.685
# [32750]	valid_0's rmse: 191.683
# [32800]	valid_0's rmse: 191.676
# [32850]	valid_0's rmse: 191.68
# [32900]	valid_0's rmse: 191.684
# [32950]	valid_0's rmse: 191.68
# [33000]	valid_0's rmse: 191.675
# [33050]	valid_0's rmse: 191.668
# [33100]	valid_0's rmse: 191.666
# [33150]	valid_0's rmse: 191.661
# [33200]	valid_0's rmse: 191.663
# [33250]	valid_0's rmse: 191.66
# [33300]	valid_0's rmse: 191.661
# [33350]	valid_0's rmse: 191.658
# [33400]	valid_0's rmse: 191.652
# [33450]	valid_0's rmse: 191.648
# [33500]	valid_0's rmse: 191.643
# [33550]	valid_0's rmse: 191.647
# [33600]	valid_0's rmse: 191.644
# [33650]	valid_0's rmse: 191.639
# [33700]	valid_0's rmse: 191.633
# [33750]	valid_0's rmse: 191.632
# [33800]	valid_0's rmse: 191.622
# [33850]	valid_0's rmse: 191.618
# [33900]	valid_0's rmse: 191.615
# [33950]	valid_0's rmse: 191.616
# [34000]	valid_0's rmse: 191.614
# [34050]	valid_0's rmse: 191.612
# [34100]	valid_0's rmse: 191.604
# [34150]	valid_0's rmse: 191.607
# [34200]	valid_0's rmse: 191.607
# [34250]	valid_0's rmse: 191.606
# [34300]	valid_0's rmse: 191.6
# [34350]	valid_0's rmse: 191.597
# [34400]	valid_0's rmse: 191.591
# [34450]	valid_0's rmse: 191.593
# [34500]	valid_0's rmse: 191.583
# [34550]	valid_0's rmse: 191.578
# [34600]	valid_0's rmse: 191.58
# [34650]	valid_0's rmse: 191.58
# [34700]	valid_0's rmse: 191.579
# [34750]	valid_0's rmse: 191.575
# [34800]	valid_0's rmse: 191.571
# [34850]	valid_0's rmse: 191.565
# [34900]	valid_0's rmse: 191.564
# [34950]	valid_0's rmse: 191.562
# [35000]	valid_0's rmse: 191.557
# [35050]	valid_0's rmse: 191.555
# [35100]	valid_0's rmse: 191.559
# [35150]	valid_0's rmse: 191.564
# [35200]	valid_0's rmse: 191.555
# [35250]	valid_0's rmse: 191.558
# [35300]	valid_0's rmse: 191.557
# [35350]	valid_0's rmse: 191.553
# [35400]	valid_0's rmse: 191.547
# [35450]	valid_0's rmse: 191.549
# [35500]	valid_0's rmse: 191.541
# [35550]	valid_0's rmse: 191.546
# [35600]	valid_0's rmse: 191.539
# [35650]	valid_0's rmse: 191.54
# [35700]	valid_0's rmse: 191.534
# [35750]	valid_0's rmse: 191.539
# [35800]	valid_0's rmse: 191.53
# [35850]	valid_0's rmse: 191.521
# [35900]	valid_0's rmse: 191.515
# [35950]	valid_0's rmse: 191.516
# [36000]	valid_0's rmse: 191.518
# [36050]	valid_0's rmse: 191.517
# [36100]	valid_0's rmse: 191.512
# [36150]	valid_0's rmse: 191.508
# [36200]	valid_0's rmse: 191.505
# [36250]	valid_0's rmse: 191.502
# [36300]	valid_0's rmse: 191.5
# [36350]	valid_0's rmse: 191.497
# [36400]	valid_0's rmse: 191.493
# [36450]	valid_0's rmse: 191.492
# [36500]	valid_0's rmse: 191.49
# [36550]	valid_0's rmse: 191.494
# [36600]	valid_0's rmse: 191.489
# [36650]	valid_0's rmse: 191.488
# [36700]	valid_0's rmse: 191.483
# [36750]	valid_0's rmse: 191.481
# [36800]	valid_0's rmse: 191.481
# [36850]	valid_0's rmse: 191.483
# [36900]	valid_0's rmse: 191.485
# [36950]	valid_0's rmse: 191.482
# [37000]	valid_0's rmse: 191.479
# [37050]	valid_0's rmse: 191.477
# [37100]	valid_0's rmse: 191.472
# [37150]	valid_0's rmse: 191.47
# [37200]	valid_0's rmse: 191.469
# [37250]	valid_0's rmse: 191.467
# [37300]	valid_0's rmse: 191.473
# [37350]	valid_0's rmse: 191.464
# [37400]	valid_0's rmse: 191.467
# [37450]	valid_0's rmse: 191.465
# [37500]	valid_0's rmse: 191.46
# [37550]	valid_0's rmse: 191.465
# [37600]	valid_0's rmse: 191.472
# [37650]	valid_0's rmse: 191.46
# [37700]	valid_0's rmse: 191.458
# [37750]	valid_0's rmse: 191.458
# [37800]	valid_0's rmse: 191.46
# [37850]	valid_0's rmse: 191.458
# [37900]	valid_0's rmse: 191.458
# [37950]	valid_0's rmse: 191.457
# [38000]	valid_0's rmse: 191.454
# [38050]	valid_0's rmse: 191.455
# [38100]	valid_0's rmse: 191.459
# [38150]	valid_0's rmse: 191.46
# [38200]	valid_0's rmse: 191.46
# [38250]	valid_0's rmse: 191.458
# [38300]	valid_0's rmse: 191.453
# [38350]	valid_0's rmse: 191.455
# [38400]	valid_0's rmse: 191.451
# [38450]	valid_0's rmse: 191.452
# [38500]	valid_0's rmse: 191.453
# [38550]	valid_0's rmse: 191.444
# [38600]	valid_0's rmse: 191.449
# [38650]	valid_0's rmse: 191.451
# [38700]	valid_0's rmse: 191.45
# [38750]	valid_0's rmse: 191.453
# [38800]	valid_0's rmse: 191.45
# [38850]	valid_0's rmse: 191.447
# [38900]	valid_0's rmse: 191.444
# [38950]	valid_0's rmse: 191.446
# [39000]	valid_0's rmse: 191.454
# [39050]	valid_0's rmse: 191.453
# Early stopping, best iteration is:
# [38556]	valid_0's rmse: 191.442

# %%
test_data = test_df.drop('Offer_Net_Weight', axis=1)
test_data.head()
# Out:
#           Garden Mark Garden Geo Orgin Manufacturing Date Tealingo Item
# 0  ASHOK KUMAR ESTATE               SI            12.2018        EG35SI
# 1  ASHOK KUMAR ESTATE               SI            12.2018        EG35SI
# 2  ASHOK KUMAR ESTATE               SI            12.2018        DG35SI
# 3  ASHOK KUMAR ESTATE               SI            12.2018        CG35SI
# 4  ASHOK KUMAR ESTATE               SI            12.2018        CG35SI

# %%
for c in test_data.columns:
    col_type = test_data[c].dtype
    if col_type == 'object' or col_type.name == 'category':
        test_data[c] = test_data[c].astype('category')
        

test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1357305 entries, 0 to 1528590
# Data columns (total 4 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   Garden Mark         1357305 non-null  category
#  1   Garden Geo Orgin    1357305 non-null  category
#  2   Manufacturing Date  1357305 non-null  category
#  3   Tealingo Item       1357305 non-null  category
# dtypes: category(4)
# memory usage: 18.4 MB

# %%
predictions = model.predict(test_data)

# %%
test_df_ori["Predicted_Offer_Net_Weight"] = predictions

# %%
test_df_ori.to_csv('output/lightGBM_2019_prediction.csv')

# %%
train_df = pd.read_csv('output/lightGBM_2019_prediction.csv',encoding = "ISO-8859-1")

# %%
train_df.tail()
